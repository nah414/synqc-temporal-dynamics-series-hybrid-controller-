# %% [markdown]
# #  — Energy‑Aware Grover Search (Qiskit)
#
# This notebook implements Grover's algorithm with:
# - A configurable **phase oracle** for one or more marked bitstrings
# - A standard **diffuser**
# - An **energy‑aware shot minimizer** using confidence‑based stopping (Hoeffding bound)
# - Simple demos you can run and tweak
#
# **Standards:**
# - Prepared for **Jupyter** (per Adam's directive)
# - Includes **Wolfram.com** references for quantum‑circuit work (per Adam's directive)
#
# > Goal: Reach target success probability (e.g., ≥60%) with **< 100 shots** when feasible.

# %% [markdown]
# ## Environment Setup
# Run the following if Qiskit isn't installed in your environment:
# ```bash
# pip install qiskit
# ```
# _You may restart the kernel after installation if needed._

# %%
# Imports
from __future__ import annotations
from dataclasses import dataclass
from typing import Iterable, List, Optional, Tuple, Dict
import math

try:
    from qiskit import QuantumCircuit, Aer, execute
    from qiskit.quantum_info import Statevector
except Exception as e:
    QuantumCircuit = object  # placeholder if qiskit not yet installed
    Aer = object
    def execute(*args, **kwargs):
        raise RuntimeError("Qiskit not available; run `pip install qiskit` and restart kernel.")
    class Statevector:
        pass

# %% [markdown]
# ## Oracle & Diffuser

# %%
def bitstring_to_int(bitstr: str) -> int:
    return int(bitstr, 2)

def build_oracle(num_qubits: int, marked: Iterable[str]) -> "QuantumCircuit":
    if isinstance(QuantumCircuit, object):
        raise RuntimeError("Qiskit not available to build the oracle")
    oracle = QuantumCircuit(num_qubits, name="Oracle")
    marked = list(marked)
    if len(marked) == 0:
        return oracle
    for s in marked:
        if len(s) != num_qubits or not set(s) <= {"0","1"}:
            raise ValueError(f"Marked string '{s}' must be {num_qubits} bits of 0/1")
        for i, b in enumerate(reversed(s)):
            if b == "0":
                oracle.x(i)
        controls = list(range(num_qubits - 1))
        target = num_qubits - 1
        oracle.h(target)
        oracle.mcx(controls, target)
        oracle.h(target)
        for i, b in enumerate(reversed(s)):
            if b == "0":
                oracle.x(i)
    return oracle

def build_diffuser(num_qubits: int) -> "QuantumCircuit":
    if isinstance(QuantumCircuit, object):
        raise RuntimeError("Qiskit not available to build the diffuser")
    diff = QuantumCircuit(num_qubits, name="Diffuser")
    for q in range(num_qubits):
        diff.h(q)
        diff.x(q)
    diff.h(num_qubits - 1)
    diff.mcx(list(range(num_qubits - 1)), num_qubits - 1)
    diff.h(num_qubits - 1)
    for q in range(num_qubits):
        diff.x(q)
        diff.h(q)
    return diff

# %% [markdown]
# ## Grover Circuit & Runner

# %% [markdown]
# ## Statevector Analysis (Pre-Measurement Amplitudes)

# %%
def analyze_statevector(cfg: GroverConfig) -> Dict[str, float]:
    """
    Build Grover circuit without measurement and extract statevector amplitudes.
    Shows amplitude distribution before measurement collapse.
    """
    if isinstance(QuantumCircuit, object) or isinstance(Statevector, object):
        raise RuntimeError("Qiskit not available for statevector analysis")
    
    # Build circuit WITHOUT measurement for statevector
    qc = QuantumCircuit(cfg.n_qubits, name="Grover_Statevector")
    for q in range(cfg.n_qubits):
        qc.h(q)
    oracle = build_oracle(cfg.n_qubits, cfg.marked)
    diffuser = build_diffuser(cfg.n_qubits)
    k = cfg.iterations if cfg.iterations is not None else optimal_iterations(cfg.n_qubits, len(cfg.marked))
    for _ in range(k):
        qc.compose(oracle, inplace=True)
        qc.compose(diffuser, inplace=True)
    
    # Compute statevector
    try:
        sv = Statevector.from_instruction(qc)
        amplitudes = sv.data
        
        # Build amplitude dict: |state> -> amplitude magnitude squared (probability)
        result = {}
        marked_set = set(cfg.marked)
        for i, amp in enumerate(amplitudes):
            prob = abs(amp) ** 2
            if prob > 1e-6:  # Only include non-negligible amplitudes
                bitstr = format(i, f'0{cfg.n_qubits}b')
                is_marked = bitstr in marked_set
                result[bitstr] = {"prob": prob, "marked": is_marked}
        
        return result
    except Exception as e:
        print(f"Statevector extraction failed: {e}")
        return {}

def print_amplitude_analysis(cfg: GroverConfig):
    """Pretty-print statevector amplitude analysis."""
    amps = analyze_statevector(cfg)
    if not amps:
        print("No amplitudes to display.")
        return
    
    marked_set = set(cfg.marked)
    marked_amps = [v["prob"] for k, v in amps.items() if v["marked"]]
    unmarked_amps = [v["prob"] for k, v in amps.items() if not v["marked"]]
    
    total_marked = sum(marked_amps) if marked_amps else 0.0
    total_unmarked = sum(unmarked_amps) if unmarked_amps else 0.0
    
    print(f"\nStatevector Analysis for {cfg.marked}:")
    print(f"  Marked states amplitude:    {total_marked:.4f}")
    print(f"  Unmarked states amplitude:  {total_unmarked:.4f}")
    print(f"\n  Top amplitudes:")
    
    sorted_amps = sorted(amps.items(), key=lambda kv: kv[1]["prob"], reverse=True)
    for bitstr, data in sorted_amps[:10]:
        mark_indicator = "✓ MARKED" if data["marked"] else "  unmarked"
        print(f"    |{bitstr}⟩  {data['prob']:.4f}  {mark_indicator}")

# %% [markdown]
# ## Circuit Metrics & Resource Analysis

# %%
def demo_circuit_metrics(n_qubits: int = 5, target: str = None):
    """Show circuit depth, gate counts, and resource usage."""
    if target is None:
        target = "1" * n_qubits
    
    cfg = GroverConfig(n_qubits=n_qubits, marked=[target], shots=1)
    qc = build_grover_circuit(cfg)
    metrics = circuit_metrics(qc)
    
    if metrics:
        print(f"\nCircuit Metrics for {n_qubits}-qubit Grover (target: {target}):")
        print(f"  Circuit depth:     {metrics['depth']}")
        print(f"  Total gates:       {metrics['total_gates']}")
        print(f"  CNOT gates:        {metrics['cnots']}")
        print(f"  Qubits used:       {metrics['num_qubits']}")
    else:
        print("Could not extract metrics.")
    
    return metrics

# %%
def optimal_iterations(n_qubits: int, num_marked: int) -> int:
    N = 2 ** n_qubits
    M = max(1, num_marked)
    return max(1, int(math.floor((math.pi/4) * math.sqrt(N / M))))

@dataclass
class GroverConfig:
    n_qubits: int
    marked: List[str]
    iterations: Optional[int] = None
    shots: int = 128
    seed_sim: Optional[int] = 1337

def build_grover_circuit(cfg: GroverConfig) -> "QuantumCircuit":
    if isinstance(QuantumCircuit, object):
        raise RuntimeError("Qiskit not available to build circuits")
    qc = QuantumCircuit(cfg.n_qubits, cfg.n_qubits, name="Grover")
    for q in range(cfg.n_qubits):
        qc.h(q)
    oracle = build_oracle(cfg.n_qubits, cfg.marked)
    diffuser = build_diffuser(cfg.n_qubits)
    k = cfg.iterations if cfg.iterations is not None else optimal_iterations(cfg.n_qubits, len(cfg.marked))
    for _ in range(k):
        qc.compose(oracle, inplace=True)
        qc.compose(diffuser, inplace=True)
    qc.measure(range(cfg.n_qubits), range(cfg.n_qubits))
    return qc

def circuit_metrics(qc: "QuantumCircuit") -> Dict[str, int]:
    """Return circuit depth and operation counts for resource analysis."""
    try:
        ops = qc.count_ops()
        return {
            "depth": qc.depth(),
            "cnots": ops.get("cx", 0),
            "total_gates": sum(ops.values()),
            "num_qubits": qc.num_qubits
        }
    except Exception:
        return {}

def run_grover(cfg: GroverConfig) -> Dict[str,int]:
    if isinstance(Aer, object):
        raise RuntimeError("Qiskit Aer not available; install per requirements.txt")
    backend = Aer.get_backend("qasm_simulator")
    if cfg.seed_sim is not None:
        backend.set_options(seed_simulator=cfg.seed_sim)
    qc = build_grover_circuit(cfg)
    job = execute(qc, backend=backend, shots=cfg.shots)
    result = job.result()
    return dict(result.get_counts(qc))

# %% [markdown]
# ## Energy‑Aware Shot Minimizer

# %%
def success_probability(counts: Dict[str, int], marked: Iterable[str]) -> float:
    total = sum(counts.values())
    if total == 0:
        return 0.0
    marked = set(marked)
    success = sum(v for k,v in counts.items() if k in marked)
    return success / total

def min_shots_for_confidence(p: float, eps: float = 0.1, delta: float = 0.05) -> int:
    if eps <= 0 or delta <= 0 or delta >= 1:
        raise ValueError("eps must be >0 and delta in (0,1)")
    n = 0.5 * (math.log(2.0/delta) / (eps**2))
    return int(math.ceil(n))

def binary_search_shots(cfg: GroverConfig,
                        target_success: float,
                        min_shots: int,
                        max_shots: int,
                        verbose: bool = True) -> Tuple[int, Dict[str,int], float]:
    """
    Binary search for minimum shots needed to achieve target success probability.
    More efficient than exponential scaling.
    """
    best_shots = max_shots
    best_counts = None
    best_success = 0.0
    
    while min_shots <= max_shots:
        mid = (min_shots + max_shots) // 2
        test_cfg = GroverConfig(
            n_qubits=cfg.n_qubits,
            marked=cfg.marked,
            iterations=cfg.iterations,
            shots=mid,
            seed_sim=cfg.seed_sim
        )
        counts = run_grover(test_cfg)
        s = success_probability(counts, cfg.marked)
        
        if verbose:
            print(f"[binary-search] shots={mid}, success≈{s:.3f} (target {target_success:.2f})")
        
        if s >= target_success:
            best_shots = mid
            best_counts = counts
            best_success = s
            max_shots = mid - 1
        else:
            min_shots = mid + 1
    
    # Ensure we return valid results
    if best_counts is None:
        test_cfg = GroverConfig(
            n_qubits=cfg.n_qubits,
            marked=cfg.marked,
            iterations=cfg.iterations,
            shots=best_shots,
            seed_sim=cfg.seed_sim
        )
        best_counts = run_grover(test_cfg)
        best_success = success_probability(best_counts, cfg.marked)
    
    return best_shots, best_counts, best_success

def energy_aware_search(cfg: GroverConfig,
                        target_success: float = 0.6,
                        eps: float = 0.1,
                        delta: float = 0.05,
                        max_shots_cap: int = 1024,
                        verbose: bool = True,
                        use_binary_search: bool = True):
    """
    Energy-aware shot minimizer using binary search or exponential scaling.
    Binary search is faster for finding the minimum shot count.
    """
    initial_shots = max(16, min(min_shots_for_confidence(target_success, eps, delta), max_shots_cap))
    
    if use_binary_search:
        return binary_search_shots(cfg, target_success, initial_shots, max_shots_cap, verbose)
    
    # Fallback: exponential scaling (original method)
    shots = initial_shots
    while shots <= max_shots_cap:
        test_cfg = GroverConfig(
            n_qubits=cfg.n_qubits,
            marked=cfg.marked,
            iterations=cfg.iterations,
            shots=shots,
            seed_sim=cfg.seed_sim
        )
        counts = run_grover(test_cfg)
        s = success_probability(counts, cfg.marked)
        if verbose:
            print(f"[energy-aware] shots={shots}, success≈{s:.3f} (target {target_success:.2f})")
        if s >= target_success:
            return shots, counts, s
        shots = min(max_shots_cap, int(math.ceil(shots * 1.8)))
    
    counts = run_grover(GroverConfig(
        n_qubits=cfg.n_qubits,
        marked=cfg.marked,
        iterations=cfg.iterations,
        shots=max_shots_cap,
        seed_sim=cfg.seed_sim
    ))
    s = success_probability(counts, cfg.marked)
    return max_shots_cap, counts, s

# %% [markdown]
# ## Quick Demos

# %%
def demo_single_marked(n_qubits: int = 5, target: str = "10101", max_shots: int = 128):
    cfg = GroverConfig(n_qubits=n_qubits, marked=[target])
    return energy_aware_search(cfg, target_success=0.6, max_shots_cap=max_shots)

def demo_multi_marked(n_qubits: int = 5, targets=None, max_shots: int = 128):
    if targets is None:
        targets = ["00011", "10101", "11100"]
    cfg = GroverConfig(n_qubits=n_qubits, marked=targets)
    return energy_aware_search(cfg, target_success=0.6, max_shots_cap=max_shots)

def demo_comparison_naive_vs_aware(n_qubits: int = 4, target: str = "1010", max_shots: int = 200):
    """
    Compare naive fixed-shot approach vs. energy-aware minimization.
    Shows the efficiency gain of adaptive shot allocation.
    """
    print("=" * 70)
    print("COMPARISON: Naive (fixed shots) vs. Energy-Aware (adaptive)")
    print("=" * 70)
    
    marked = [target]
    cfg = GroverConfig(n_qubits=n_qubits, marked=marked, seed_sim=None)  # No seed for realistic variance
    
    # Naive approach: fixed high shot count
    print("\n[NAIVE] Running with fixed max_shots=200 (no adaptation)...")
    naive_cfg = GroverConfig(
        n_qubits=n_qubits,
        marked=marked,
        shots=max_shots,
        seed_sim=None
    )
    naive_counts = run_grover(naive_cfg)
    naive_success = success_probability(naive_counts, marked)
    print(f"  Shots used: {max_shots}, Success: {naive_success:.3f}")
    
    # Energy-aware approach: adaptive
    print("\n[ENERGY-AWARE] Running adaptive search...")
    aware_shots, aware_counts, aware_success = energy_aware_search(
        cfg, 
        target_success=0.6, 
        max_shots_cap=max_shots,
        use_binary_search=True,
        verbose=False
    )
    print(f"  Shots used: {aware_shots}, Success: {aware_success:.3f}")
    
    # Summary
    print("\n" + "=" * 70)
    print("SUMMARY:")
    print(f"  Naive approach:      {max_shots} shots")
    print(f"  Energy-aware:        {aware_shots} shots")
    savings = 100 * (1 - aware_shots / max_shots)
    print(f"  Efficiency gain:     {savings:.1f}% shot reduction")
    print("=" * 70)
    
    return {
        "naive": {"shots": max_shots, "success": naive_success},
        "aware": {"shots": aware_shots, "success": aware_success}
    }

# %% [markdown]
# ### Run a simple demo

# %%
# Try to reach ≥60% success with ≤96 shots
try:
    used, counts, s = demo_single_marked(n_qubits=5, target="10101", max_shots=96)
    print("used_shots:", used)
    print("success_estimate:", round(s, 3))
    print("top counts:", dict(sorted(counts.items(), key=lambda kv: kv[1], reverse=True)[:5]))
except Exception as e:
    print("Run failed — likely missing Qiskit. Install it and retry.\n", e)

# %% [markdown]
# ### Statevector Analysis Demo

# %%
try:
    cfg = GroverConfig(n_qubits=4, marked=["1010"])
    print_amplitude_analysis(cfg)
except Exception as e:
    print(f"Statevector analysis failed: {e}")

# %% [markdown]
# ### Circuit Metrics Demo

# %%
try:
    demo_circuit_metrics(n_qubits=5, target="10101")
except Exception as e:
    print(f"Metrics demo failed: {e}")

# %% [markdown]
# ### Naive vs. Energy-Aware Comparison Demo

# %%
try:
    comparison = demo_comparison_naive_vs_aware(n_qubits=4, target="1010", max_shots=180)
except Exception as e:
    print(f"Comparison demo failed: {e}")

# %% [markdown]
# ## Hardware & Optimization Tips
# - Enable measurement error mitigation if available.
# - Use dynamical decoupling / echo sequences when appropriate.
# - Calibrate the Grover iteration count against your target device.
# - Consider randomized compiling to reduce coherent errors.
# - If latency dominates, prefer a few higher‑confidence batches over many tiny batches.

# %% [markdown]
# ## Theory (checked with Wolfram.com)
#
# - **Grover iteration**: The operator is the product of an oracle phase flip and the **diffusion operator** \(U_s = 2|s\rangle\langle s| - I\), which reflects about the uniform superposition \(|s\rangle\). See the Wolfram Example Repository entry on *Grover's search algorithm* and the Demonstrations Project write-ups.
#   - Example Repository (Wolfram Cloud): https://resources.wolframcloud.com/ExampleRepository/resources/Grovers-search-algorithm/
#   - Demonstration — *Quantum Circuit Implementing Grover's Search Algorithm*: https://demonstrations.wolfram.com/QuantumCircuitImplementingGroversSearchAlgorithm/
#   - Demonstration — *Grover's Quantum Search Algorithm*: https://demonstrations.wolfram.com/GroversQuantumSearchAlgorithm/
#
# - **Optimal number of iterations**: For \(N=2^n\) items and \(M\) marked states, a common approximation is
#   \[ k \approx \left\lfloor \frac{\pi}{4}\sqrt{\frac{N}{M}} \right\rfloor. \]
#   This is consistent with standard presentations (see references above) and aligns with the geometry-of-rotations view.
#
# The notebook's oracle/diffuser implementation and the iteration formula match these sources.

# %% [markdown]
# ## References (incl. Wolfram.com)
# - **Wolfram Example Repository — Grover's Search**: https://resources.wolframcloud.com/ExampleRepository/resources/Grovers-search-algorithm/
# - **Wolfram Demonstrations — Quantum Circuit Implementing Grover**: https://demonstrations.wolfram.com/QuantumCircuitImplementingGroversSearchAlgorithm/
# - **Wolfram Demonstrations — Grover's Quantum Search Algorithm**: https://demonstrations.wolfram.com/GroversQuantumSearchAlgorithm/
# - **Qiskit Textbook — Grover's Algorithm**: https://qiskit.org/textbook/ch-algorithms/grover.html
